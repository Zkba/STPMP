# %% [markdown]
# <a href="https://colab.research.google.com/github/Zkba/STPMP/blob/main/run_train_3dpw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
data_path = '/content/drive/My Drive/3dpwDataset'
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/JasonWang959/STPMP.git
# %cd STPMP

# !pip install progress
# Out:
# Cloning into 'STPMP'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 88 (delta 24), reused 52 (delta 11), pack-reused 13
# Receiving objects: 100% (88/88), 487.09 MiB | 18.49 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Updating files: 100% (36/36), done.
# /content/STPMP
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9614 sha256=ed0628ae184b4ebe466b94416d3a527d574ac31dea0bb073be58992b49bfdf27
#   Stored in directory: /root/.cache/pip/wheels/a2/68/5f/c339b20a41659d856c93ccdce6a33095493eb82c3964aac5a1
# Successfully built progress
# ...

# %%
# !nvidia-smi
# Out:
# Wed Jul  3 15:47:04 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !CUDA_VISIBLE_DEVICES={0} python main_3dpw_3d.py --t_input_size=69 --s_input_size=40 --input_n=10 --output_n=30 --dct_n=40
# Out:
# ==================Options=================
# {   'actions': 'all',
#     'ckpt': 'checkpoint/test',
#     'data_dir': '/data00/jiexin_wang/datasets/human3.6/h3.6m/dataset',
#     'data_dir_3dpw': '/content/drive/MyDrive/3dpwDataset/sequenceFiles',
#     'data_dir_cmu': '/data00/jiexin_wang/datasets/CMUMocap/',
#     'dct_n': 40,
#     'dropout': 0.3,
#     'encoder': 'GCN',
#     'epochs': 100,
#     'exp': 'test',
#     'factor': 2,
#     'granularity': 4,
#     'hidden_size': 512,
#     'input_n': 10,
#     'is_load': False,
#     'is_norm': False,
#     'is_norm_dct': False,
#     'job': 10,
#     'kernel_size': 2,
#     'lr': 0.001,
#     'lr_decay': 2,
#     'lr_gamma': 0.96,
#     'num_head': 4,
#     'num_layer': 1,
#     'output_n': 30,
#     'padding': 1,
#     's_input_size': 40,
#     'sample_rate': 2,
#     'stride': 1,
#     't_input_size': 69,
#     'test_batch': 128,
#     'train_batch': 32}
# ...
#
# >>> creating model
# >>> loading data
# ...

# %%
# !git remote add origin https://github.com/Zkba/STPMP.git
# Out:
# checkpoint  image  main_3dpw_3d.py  main_cmu_3d.py  main_h36m_3d.py  README.md	utils
